# %% [markdown]
# # Image Steganography Lab Setup
#
# Use this notebook to prepare the environment for the scaffolded steganography exercise.

# %%
# !pip install pillow

# %% [markdown]
# ## Upload the scaffold ZIP
# Upload `steg_scaffold_student.zip`, then run the next cell.

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !unzip -o steg_scaffold_student.zip
# %cd steg_scaffold_student
# !ls

# %% [markdown]
# ## Upload a BMP cover image
# The scaffold expects a BMP image. You can rename it or update `coverImage` inside `embed.py`.

# %%
uploaded = files.upload()
# !ls

# %% [markdown]
# ## Run after completing the TODOs

# %%
# !python embed.py
# !python extract.py
